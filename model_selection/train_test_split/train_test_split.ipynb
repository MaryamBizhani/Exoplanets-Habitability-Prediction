# %%
# import libraries

import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedGroupKFold, StratifiedKFold

# %%
df = pd.read_csv('../../data/processed/categorized_data.csv')
df.head()
# Out:
#                   P_NAME   P_DETECTION P_DISCOVERY_FACILITY  P_YEAR  P_MASS  \
# 0  OGLE-2016-BLG-1227L b  Microlensing                 OGLE    2020  250.00
# 1           Kepler-276 c       Transit               Kepler    2013   16.60
# 2           Kepler-829 b       Transit               Kepler    2016    5.10
# 3               K2-283 b       Transit                   K2    2018   12.20
# 4           Kepler-477 b       Transit               Kepler    2016    4.94
#
#       P_MASS_ORIGIN  P_RADIUS   P_PERIOD  P_SEMI_MAJOR_AXIS  P_ECCENTRICITY  \
# 0              Mass     13.90        NaN             3.4000             NaN
# 1              Mass      2.90  31.884000             0.1994             0.0
# 2  M-R relationship      2.11   6.883376             0.0678             0.0
# 3  M-R relationship      3.52   1.921036             0.0291             NaN
# 4  M-R relationship      2.07  11.119907             0.0911             0.0
#
#    ...  S_LUMINOSITY  S_SNOW_LINE S_ABIO_ZONE S_TIDAL_LOCK  P_HABZONE_OPT  \
# 0  ...           NaN          NaN         NaN     0.214133              0
# 1  ...      0.814704     2.437046    2.097783     0.316980              0
# 2  ...      1.096478     2.827247    1.756317     0.459559              0
# 3  ...      0.299226     1.476943    0.568374     0.443760              0
# 4  ...      0.424620     1.759397    0.768502     0.386150              0
#
#    P_HABZONE_CON  P_TYPE_TEMP  P_HABITABLE     P_ESI  HABITABILITY
# 0              0          NaN            0       NaN             0
# 1              0          Hot            0  0.272032             0
# 2              0          Hot            0  0.254763             0
# 3              0          Hot            0  0.193906             0
# 4              0          Hot            0  0.276721             0
#
# [5 rows x 47 columns]

# %%
df.describe().T
# Out:
#                     count          mean           std           min  \
# P_YEAR             5599.0  2.016189e+03  4.527714e+00  1.992000e+03
# P_MASS             5592.0  4.425213e+02  2.369505e+03  2.000000e-02
# P_RADIUS           5592.0  5.715494e+00  5.331450e+00  3.100000e-01
# P_PERIOD           5350.0  7.994082e+04  5.498596e+06  9.070629e-02
# P_SEMI_MAJOR_AXIS  5595.0  6.307151e+00  1.306763e+02  4.400000e-03
# P_ECCENTRICITY     4822.0  7.640731e-02  1.505245e-01  0.000000e+00
# P_INCLINATION      4288.0  8.686255e+01  1.055637e+01  3.700000e-01
# P_OMEGA            1659.0  1.190260e+02  1.194222e+02 -2.330000e+02
# S_MAG              5380.0  1.263606e+01  3.101634e+00  8.720000e-01
# S_DISTANCE         5578.0  6.966242e+02  1.106374e+03  1.301190e+00
# S_TEMPERATURE      5380.0  5.430370e+03  1.777910e+03  4.150000e+02
# S_MASS             5595.0  9.502377e-01  4.232341e-01  1.000000e-02
# S_RADIUS           5367.0  1.545746e+00  4.197689e+00  1.000000e-02
# S_METALLICITY      5166.0  1.370596e-02  2.134586e-01 -1.000000e+00
# S_AGE              4392.0  4.374456e+00  3.086707e+00  1.000000e-03
# S_LOG_LUM          5364.0 -1.153123e-01  7.590245e-01 -6.090000e+00
# S_LOG_G            5353.0  4.375857e+00  4.414455e-01  5.400000e-01
# P_ESCAPE           5592.0  3.663400e+00  4.683182e+00  2.432521e-01
# P_POTENTIAL        5592.0  3.534877e+01  1.369108e+02  5.917160e-02
# P_GRAVITY          5592.0  3.965438e+00  1.402954e+01  3.808594e-02
# P_DENSITY          5592.0  1.144261e+00  1.340580e+01  5.486968e-03
# P_HILL_SPHERE      5587.0  1.171400e+00  2.586185e+01  5.751274e-05
# P_DISTANCE         5595.0  6.384991e+00  1.307987e+02  4.407920e-03
# P_PERIASTRON       5595.0  6.015929e+00  1.303923e+02  4.136000e-03
# P_APASTRON         5595.0  6.598373e+00  1.311885e+02  4.664000e-03
# P_DISTANCE_EFF     5595.0  6.330281e+00  1.307099e+02  4.401982e-03
# P_FLUX             5365.0  8.430605e+02  1.745120e+04  3.289901e-10
# P_TEMP_EQUIL       5365.0  7.929856e+02  4.844342e+02  1.084914e+00
# P_TEMP_SURF        2441.0  9.719940e+02  4.873829e+02  1.306617e+02
# S_LUMINOSITY       5366.0  8.007960e+00  1.110798e+02  8.128305e-07
# S_SNOW_LINE        5366.0  3.596167e+00  6.741964e+00  2.434242e-03
# S_ABIO_ZONE        5376.0  1.014471e+35  5.259131e+36  4.356319e-05
# S_TIDAL_LOCK       5595.0  4.257903e-01  7.706420e-02  2.926926e-02
# P_HABZONE_OPT      5599.0  4.715128e-02  2.119813e-01  0.000000e+00
# P_HABZONE_CON      5599.0  3.357742e-02  1.801549e-01  0.000000e+00
# P_HABITABLE        5599.0  1.982497e-02  1.846172e-01  0.000000e+00
# P_ESI              5358.0  2.570892e-01  1.316216e-01  2.389554e-02
# HABITABILITY       5599.0  1.250223e-02  1.111221e-01  0.000000e+00
#
#                            25%          50%          75%           max
# P_YEAR             2014.000000  2016.000000  2020.000000  2.024000e+03
# P_MASS                4.040000     8.750000   162.092490  8.970000e+04
# P_RADIUS              1.780000     2.780000    11.900000  7.734200e+01
# P_PERIOD              4.465382    11.569511    41.505555  4.020000e+08
# P_SEMI_MAJOR_AXIS     0.052750     0.102100     0.284600  7.506000e+03
# P_ECCENTRICITY        0.000000     0.000000     0.090000  9.500000e-01
# P_INCLINATION        86.900000    88.760500    89.670000  1.760920e+02
# P_OMEGA              28.300000   104.490000   210.000000  3.953410e+02
# S_MAG                10.837500    13.466000    15.009000  4.461000e+01
# S_DISTANCE          112.467000   407.100500   852.046500  8.500000e+03
# S_TEMPERATURE      4942.750000  5555.000000  5902.000000  5.700000e+04
# S_MASS                0.790000     0.950000     1.090000  1.094000e+01
# S_RADIUS              0.780000     0.960000     1.250000  1.094600e+02
# S_METALLICITY        -0.080000     0.020000     0.120000  7.790000e+00
# S_AGE                 2.340000     3.980000     5.377500  1.490000e+01
# S_LOG_LUM            -0.446000    -0.066000     0.314000  3.800000e+00
# S_LOG_G               4.290000     4.450000     4.570000  7.920000e+00
# P_ESCAPE              1.478746     1.747638     3.704670  5.245506e+01
# P_POTENTIAL           2.186689     3.054237    13.724583  2.751534e+03
# P_GRAVITY             1.019771     1.165634     1.587571  3.879761e+02
# P_DENSITY             0.249191     0.477166     0.849771  7.478270e+02
# P_HILL_SPHERE         0.001198     0.002431     0.006904  1.318169e+03
# P_DISTANCE            0.053032     0.102800     0.286450  7.506000e+03
# P_PERIASTRON          0.050765     0.098000     0.260000  7.506000e+03
# P_APASTRON            0.054515     0.105600     0.297000  7.506000e+03
# P_DISTANCE_EFF        0.052847     0.102279     0.286150  7.506000e+03
# P_FLUX               10.531771    67.353048   292.334460  8.793103e+05
# P_TEMP_EQUIL        456.758880   727.306290  1049.902400  7.800730e+03
# P_TEMP_SURF         638.352490   908.701120  1204.326300  8.125496e+03
# S_LUMINOSITY          0.358096     0.859014     2.058263  6.309573e+03
# S_SNOW_LINE           1.615711     2.502441     3.873593  2.144686e+02
# S_ABIO_ZONE           0.478109     1.361846     2.556535  2.726899e+38
# S_TIDAL_LOCK          0.391256     0.443760     0.470516  1.003328e+00
# P_HABZONE_OPT         0.000000     0.000000     0.000000  1.000000e+00
# P_HABZONE_CON         0.000000     0.000000     0.000000  1.000000e+00
# P_HABITABLE           0.000000     0.000000     0.000000  2.000000e+00
# P_ESI                 0.186192     0.268055     0.301299  9.683624e-01
# HABITABILITY          0.000000     0.000000     0.000000  1.000000e+00

# %%
df['HABITABILITY'].value_counts()
# Out:
# HABITABILITY
# 0    5529
# 1      70
# Name: count, dtype: int64

# %%
# calculate the imbalance ratio
imbalance_ratio = df['HABITABILITY'].value_counts()[0] / df['HABITABILITY'].value_counts()[1]
print(f'Imbalance Ratio (Class 0 to Class 1): {imbalance_ratio:.2f}')
# Out:
# Imbalance Ratio (Class 0 to Class 1): 78.99

# %% [markdown]
# Given the imbalance ratio, we can see that the dataset is imbalanced, with significantly more non-habitable exoplanets than habitable ones. This information will be crucial when selecting appropriate modeling techniques and evaluation metrics to ensure that our model performs well across both classes.
#
# In addition, we would like to avoid star properties leakage when spliting the train and test data.
# To split train test data we try stratified groupfold method.

# %%
X = df.drop(columns=['HABITABILITY'])
y = df['HABITABILITY']
groups = df['S_NAME']

sgkf = StratifiedGroupKFold(n_splits=3, shuffle=True, random_state=42)
for train_idx, test_idx in sgkf.split(X, y, groups):
    df_train = df.iloc[train_idx]
    df_test = df.iloc[test_idx]
    break # only need the first split for train_test split

print("Total exoplanets:", len(df))
print("Train_size:", len(df_train)/len(df))
print("Test_size:", len(df_test)/len(df))
print("Train_set_total", len(df_train))
print("Test_set_total", len(df_test))

print("Train HABITABILITY distribution:")
print(df_train['HABITABILITY'].value_counts())
print("Test HABITABILITY distribution:")
print(df_test['HABITABILITY'].value_counts())

# Check for data leakage
print("Unique stars in train:", set(df_train['S_NAME'].unique()))
print("Unique stars in test:", set(df_test['S_NAME'].unique()))
print("Common stars in train and test:", set(df_train['S_NAME'].unique()) & set(df_test['S_NAME'].unique()))
print("Number of common stars:", len(set(df_train['S_NAME'].unique()) & set(df_test['S_NAME'].unique())))
# Out:
# Total exoplanets: 5599
# Train_size: 0.6706554741918199
# Test_size: 0.32934452580818
# Train_set_total 3755
# Test_set_total 1844
# Train HABITABILITY distribution:
# HABITABILITY
# 0    3704
# 1      51
# Name: count, dtype: int64
# Test HABITABILITY distribution:
# HABITABILITY
# 0    1825
# 1      19
# Name: count, dtype: int64
# Unique stars in train: {'OGLE-2012-BLG-0358L', 'HD 110067', 'Kepler-1444', 'HD 163607', 'HD 100655', 'Kepler-290', 'HD 114613', 'HD 134606', 'Kepler-1293', 'TOI-1693', 'TOI-444', 'Kepler-1266', 'MOA-2009-BLG-266L', 'OGLE-2017-BLG-0173L', 'TOI-201', 'HD 216770', 'Kepler-1892', 'Kepler-727', 'HD 108874', 'AU Mic', '18 Del', 'K2-167', 'WASP-186', 'Kepler-338', 'Kepler-1282', 'Kepler-1748', 'TOI-451', 'Kepler-1093', 'Kepler-1524', 'Kepler-285', 'OGLE-2016-BLG-1067L', 'BD-00 4475', 'EPIC 246851721', 'Kepler-550', 'Kepler-593', 'Kepler-554', 'Kepler-77', 'HAT-P-65', 'Kepler-1142', 'HD 189567', 'HD 26161', 'Kepler-1180', 'Kepler-1952', 'Kepler-1684', 'Kepler-1490', 'Kepler-708', 'Kepler-644', 'Kepler-179', 'K2-138', 'Kepler-1882', 'GJ 4276', 'LHS 475', 'Kepler-1307', 'Kepler-1528', 'WASP-148', 'Kepler-1022', 'HATS-32', 'Kepler-1063', 'TOI-1278', 'Kepler-1661', 'K2-241', 'HU Aqr', 'Kepler-817', 'Kepler-332', 'Kepler-1271', 'WASP-36', 'Kepler-1595', 'Kepler-620', 'HD 104067', 'Kepler-96', 'Kepler-1207', 'HD 29399', 'Kepler-1326', 'K2-289', 'Kepler-311', 'Kepler-577', 'WASP-132', 'Kepler-444', 'HAT-P-22', 'Kepler-305', 'K2-189', 'Kepler-234', 'Kepler-1384', 'Kepler-713', 'Kepler-810', 'Kepler-1735', 'TOI-2109', 'HD 43197', 'OGLE-2018-BLG-0596L', 'Kepler-196', 'PDS 70', 'WASP-75', 'TOI-1669', 'HD 9174', 'HD 260655', 'K2-214', 'GJ 9066', 'KMT-2016-BLG-2142L', 'HD 148427', 'HATS-65', 'Kepler-259', 'CoRoT-6', 'CoRoT-11', 'BD+49 828', 'CoRoT-21', 'Kepler-454', 'Kepler-1002', 'K2-243', 'HD 166724', 'TOI-858 B', 'TOI-2285', 'NGTS-3 A', 'K2-139', 'Kepler-1978', 'TOI-559', 'Kepler-1310', 'K2-161', 'Kepler-92', 'HD 103720', 'HD 145377', 'Kepler-1174', 'Kepler-1060', 'K2-413', 'Kepler-1156', 'K2-405', 'TOI-1442', 'WASP-57', 'KELT-2 A', 'WASP
66', 'KMT-2020-BLG-0414L', 'TOI-262', 'HIP 107773', 'HD 238090', 'HD 16141', 'Kepler-1190', 'Kepler-421', 'Kepler-580', 'Kepler-108', 'Kepler-314', 'WASP-187', 'HD 82943', 'K2-242', 'K2-392', 'KIC 9663113', 'Kepler-1666', 'Kepler-1416', 'K2-104', 'Kepler-1179', 'HD 125390', 'K2-386', 'HD 97658', 'Kepler-1327', 'HD 103197', 'Kepler-1283', 'Kepler-813', 'Kepler-736', 'Kepler-743', 'TOI-1408', 'HD 12235', 'SR 12 AB', 'Pr0211', 'TOI-238', 'Kepler-1753', 'Kepler-1896', 'TOI-3884', 'Kepler-463', 'K2-269', 'HD 181342', 'Kepler-1257', 'HD 191806', 'WASP-104', 'HD 1666', 'Kepler-1991', 'Kepler-206', 'Kepler-696', 'WASP-52', 'Kepler-1148', 'TOI-4551', 'HD 21693', 'Kepler-1536', 'KOI-1783', 'Kepler-40', 'Qatar-5', 'XO-1', 'Kepler-1253', 'WASP-59', 'TIC 172900988 Aa', 'HD 113337', 'HD 143105', 'Kepler-572', 'Kepler-513', 'Kepler-750', 'Kepler-49', 'HD 10647', 'Kepler-1214', 'Kepler-1953', 'TOI-558', 'OGLE-2017-BLG-1522L', 'Kepler-1547', 'Kepler-1800', 'Kepler-784', 'MOA-2010-BLG-353L', 'GJ 27.1', 'Kepler-1131', 'K2-3', 'TOI-824', 'Kepler-1747', 'TYC 3667-1280-1', 'Kepler-1843', 'WASP-150', 'EPIC 248847494', 'K2-50', 'HIP 75092', 'SWEEPS-4', 'GJ 667 C', 'GJ 414 A', 'Kepler-604', 'Kepler-1512', 'XO-2 S', 'HIP 97233', 'Kepler-1618', 'GJ 1132', 'Kepler-1915', 'HAT-P-29', 'K2-123', 'Kepler-313', 'Kepler-563', 'HD 5608', 'Kepler-1111', 'KOI-7892', 'HD 130322', 'Kepler-1045', 'TOI-270', 'LHS 3844', 'HD 114729', 'DE CVn', 'Kepler-771', 'Kepler-1850', 'HD 153950', 'OGLE-2013-BLG-0911L', 'Kepler-1517', 'Kepler-1593', 'Kepler-151', 'LHS 1478', 'HD 12661', 'Kepler-1225', 'Kepler-237', '30 Ari B', 'K2-114', 'Kepler-1323', 'Kepler-1385', 'Kepler-466', 'Kepler-542', 'Kepler-1474', 'KMT-2019-BLG-0335L', 'Kepler-1711', 'HD 136418', 'Kepler-566', 'Kepler-825', 'NGTS-14 A', 'Kepler-1048', 'K2-9', 'OGLE-2018-BLG-1367L', 'K2-220', 'Kepler-700', 'KMT-2021-BLG-0320L', 'Kepler-1233', 'K2-337', 'HD 64121', 'Kepler-1494', 'Kepler-17', 'HD 106906', 'K2-183', 'HD 11506', 'TOI-4377', 'HD ...
# Common stars in train and test: set()
# Number of common stars: 0

# %%
# save the splits and put the test set aside for final evaluation
df_train.to_csv("../../data/processed/train_phl.csv", index=False)
df_test.to_csv("../../data/processed/test_phl.csv", index=False)
